# %%
import xml.etree.ElementTree as ET
import pandas as pd

# Parse the XML file
tree = ET.parse("021525.xml")
root = tree.getroot()

# Create empty lists to hold data for DataFrames
hosts_data = []
ports_data = []
scans_data = []

# Extract scan metadata
scan_command = root.attrib.get('args', 'Unknown')
scans_data.append({'scan_command': scan_command})

# Process each host in the XML file
for host in root.findall("host"):
    # Extract host information
    ip_address = None
    mac_address = None
    hostname = None
    os = None
    status = None

    # IP address
    ip_elem = host.find("address[@addrtype='ipv4']")
    if ip_elem is not None:
        ip_address = ip_elem.attrib['addr']

    # MAC address
    mac_elem = host.find("address[@addrtype='mac']")
    if mac_elem is not None:
        mac_address = mac_elem.attrib['addr']

    # Hostname
    hostname_elem = host.find("hostnames/hostname")
    if hostname_elem is not None:
        hostname = hostname_elem.attrib.get('name', None)

    # Operating System
    os_elem = host.find("os/osmatch")
    if os_elem is not None:
        os = os_elem.attrib.get('name', None)

    # Status
    status_elem = host.find("status")
    if status_elem is not None:
        status = status_elem.attrib.get('state', None)

    # Append host data to the list
    hosts_data.append({
        'ip_address': ip_address,
        'mac_address': mac_address,
        'hostname': hostname,
        'os': os,
        'status': status
    })

    # Process ports
    for port in host.findall("ports/port"):
        port_number = port.attrib.get('portid', None)
        protocol = port.attrib.get('protocol', None)
        state = None
        service = None
        version = None

        # State
        state_elem = port.find("state")
        if state_elem is not None:
            state = state_elem.attrib.get('state', None)

        # Service
        service_elem = port.find("service")
        if service_elem is not None:
            service = service_elem.attrib.get('name', None)
            version = service_elem.attrib.get('version', None)

        # Append port data to the list
        ports_data.append({
            'ip_address': ip_address,
            'port_number': port_number,
            'protocol': protocol,
            'state': state,
            'service': service,
            'version': version
        })

# Convert lists to Pandas DataFrames
scans_df = pd.DataFrame(scans_data)
hosts_df = pd.DataFrame(hosts_data)
ports_df = pd.DataFrame(ports_data)

# Display the DataFrames
print("Scan Metadata:")
print(scans_df)

print("\nHosts Data:")
print(hosts_df)

print("\nPorts Data:")
print(ports_df)
# Out:
# Scan Metadata:
#                      scan_command
# 0  nmap -sV -O -v 192.168.55.0/24
#
# Hosts Data:
#          ip_address        mac_address                     hostname  \
# 0      192.168.55.0               None                         None
# 1      192.168.55.2               None                         None
# 2      192.168.55.3               None                         None
# 3      192.168.55.4               None                         None
# 4      192.168.55.5               None                         None
# ..              ...                ...                          ...
# 251  192.168.55.250  90:09:D0:14:E5:F7                         None
# 252  192.168.55.251  02:42:C0:A8:37:FB                      pi.hole
# 253  192.168.55.252  02:42:C0:A8:37:FC                         None
# 254  192.168.55.253  02:42:C0:A8:37:FD                         None
# 255   192.168.55.10               None  timdesktop.larsonsplace.com
#
#                                       os status
# 0                                   None   down
# 1                                   None   down
# 2                                   None   down
# 3                                   None   down
# 4                                   None   down
# ..                                   ...    ...
# 251                     Linux 3.2 - 4.14     up
# 252                     Linux 3.2 - 4.14     up
# 253                     Linux 3.2 - 4.14     up
# 254               Aruba ArubaOS-CX 10.04     up
# 255  Microsoft Windows 10 1607 - 11 23H2     up
#
# [256 rows x 5 columns]
#
# Ports Data:
#         ip_address port_number protocol state       service version
# 0     192.168.55.1          53      tcp  open        domain    None
# 1    192.168.55.12        5000      tcp  open          rtsp    None
# 2    192.168.55.13        8088      tcp  open    radan-http    None
# 3    192.168.55.14          53      tcp  open        domain    2.80
# 4    192.168.55.14          80      tcp  open          http   1.0.0
# ..             ...         ...      ...   ...           ...     ...
# 224  192.168.55.10         135      tcp  open         msrpc    None
# 225  192.168.55.10         139      tcp  open   netbios-ssn    None
# 226  192.168.55.10         445      tcp  open  microsoft-ds    None
# 227  192.168.55.10        2968      tcp  open          enpp    None
# 228  192.168.55.10        8080      tcp  open          http    None
#
# [229 rows x 6 columns]

# %%
hosts_df
# Out:
#          ip_address        mac_address                     hostname  \
# 0      192.168.55.0               None                         None
# 1      192.168.55.2               None                         None
# 2      192.168.55.3               None                         None
# 3      192.168.55.4               None                         None
# 4      192.168.55.5               None                         None
# ..              ...                ...                          ...
# 251  192.168.55.250  90:09:D0:14:E5:F7                         None
# 252  192.168.55.251  02:42:C0:A8:37:FB                      pi.hole
# 253  192.168.55.252  02:42:C0:A8:37:FC                         None
# 254  192.168.55.253  02:42:C0:A8:37:FD                         None
# 255   192.168.55.10               None  timdesktop.larsonsplace.com
#
#                                       os status
# 0                                   None   down
# 1                                   None   down
# 2                                   None   down
# 3                                   None   down
# 4                                   None   down
# ..                                   ...    ...
# 251                     Linux 3.2 - 4.14     up
# 252                     Linux 3.2 - 4.14     up
# 253                     Linux 3.2 - 4.14     up
# 254               Aruba ArubaOS-CX 10.04     up
# 255  Microsoft Windows 10 1607 - 11 23H2     up
#
# [256 rows x 5 columns]

# %%
with pd.ExcelWriter("nmap_results.xlsx") as writer:
    scans_df.to_excel(writer, sheet_name="Scan Metadata", index=False)
    hosts_df.to_excel(writer, sheet_name="Hosts", index=False)
    ports_df.to_excel(writer, sheet_name="Ports", index=False)

# %%
nmap_host_up_df = pd.read_csv("nmap_up_01.csv", encoding="utf-8")

# %%
nmap_host_up_df
# Out:
#         ip_address        mac_address                       hostname  \
# 0     192.168.55.1  F0:AD:4E:26:D9:54                            NaN
# 1    192.168.55.12  52:1B:A6:A7:FD:36                            NaN
# 2    192.168.55.13  84:72:07:7B:20:4F                            NaN
# 3    192.168.55.14  A0:40:A0:67:60:18                            NaN
# 4    192.168.55.15  B0:68:E6:ED:C0:8F                            NaN
# 5    192.168.55.18  10:27:F5:7A:A9:7E                            NaN
# 6    192.168.55.19  64:52:99:5C:7D:98                            NaN
# 7    192.168.55.20  A0:40:A0:67:4C:77                            NaN
# 8    192.168.55.22  C8:69:CD:11:67:14       appletv.larsonsplace.com
# 9    192.168.55.24  78:E1:03:45:7C:F5                            NaN
# 10   192.168.55.26  A0:40:A0:67:4D:E4                            NaN
# 11   192.168.55.27  BC:EC:43:41:94:0C  vickydesktop.larsonsplace.com
# 12   192.168.55.28  4C:EF:C0:D2:88:1F                            NaN
# 13   192.168.55.29  4C:EF:C0:6C:20:2A                            NaN
# 14   192.168.55.30  E2:32:32:0D:3F:CA     vickyipad.larsonsplace.com
# 15   192.168.55.31  A4:08:01:B1:51:28                            NaN
# 16   192.168.55.37  84:A3:29:56:81:2C                            NaN
# 17   192.168.55.40  6C:2F:80:51:CC:5A                            NaN
# 18   192.168.55.41  08:02:8E:9D:94:A0                            NaN
# 19   192.168.55.42  B0:60:88:40:84:86   qirmbl6305e.larsonsplace.com
# 20   192.168.55.44  44:3D:54:F8:38:EB                            NaN
# 21   192.168.55.47  00:BE:43:F3:BB:4D                            NaN
# 22   192.168.55.49  02:8A:A3:8E:5C:F3                            NaN
# 23   192.168.55.51  AA:C4:A4:27:48:15                            NaN
# 24   192.168.55.56  B0:09:DA:93:D1:3F                            NaN
# 25   192.168.55.59  74:AB:93:2E:B8:8D                            NaN
# 26   192.168.55.63  3C:E4:41:BA:78:3E                            NaN
# 27   192.168.55.64  44:61:32:1C:7D:C4                            NaN
# 28   192.168.55.67  7A:70:C9:4A:D5:2A                            NaN
# 29   192.168.55.76  D6:2B:E7:58:B9:1D                            NaN
# 30   192.168.55.80  74:D4:23:75:6F:CC                            NaN
# 31   192.168.55.83  E0:BB:9E:14:54:AB                            NaN
# 32   192.168.55.85  9E:4C:D0:57:68:B0                            NaN
# 33   192.168.55.90  44:3D:54:F8:6D:67                            NaN
# 34  192.168.55.250  90:09:D0:14:E5:F7                            NaN
# 35  192.168.55.251  02:42:C0:A8:37:FB                        pi.hole
# 36  192.168.55.252  02:42:C0:A8:37:FC                            NaN
# 37  192.168.55.253  02:42:C0:A8:37:FD                            NaN
# 38   192.168.55.10                NaN    timdesktop.larsonsplace.com
#
#                                                    os status
# 0                                FreeBSD 11.2-RELEASE     up
# 1   Apple macOS 11 (Big Sur) - 13 (Ventura) or iOS...     up
# 2                                                 NaN     up
# 3   OpenWrt Chaos Calmer 15.05 (Linux 3.18) or Des...     up
# 4                     Brother or HP printer (VxWorks)     up
# 5                                  lwIP 1.4.1 - 2.0.3     up
# 6                  Chamberlain myQ garage door opener     up
# 7   OpenWrt Chaos Calmer 15.05 (Linux 3.18) or Des...     up
# 8   Apple iOS 14.0 - 15.6 or tvOS 14.3 - 16.1 (Dar...     up
# 9                                    Linux 3.2 - 4.14     up
# 10  OpenWrt Chaos Calmer 15.05 (Linux 3.18) or Des...     up
# 11                          Microsoft Windows 10 1803     up
# 12                                   Linux 3.2 - 4.14     up
# 13                                   Linux 3.2 - 4.14     up
# 14  Apple iOS 14.0 - 15.6 or tvOS 14.3 - 16.1 (Dar...     up
# 15               Android 4.1 - 6.0 (Linux 3.4 - 3.14)     up
# 16                                                NaN     up
# 17                                                NaN     up
# 18                                                NaN     up
# 19                                                NaN     up
# 20                     Honeywell T5+ or T6 Thermostat     up
# 21                                  Linux 4.15 - 5.19     up
# 22     Apple iOS 15.0 - 15.6 (Darwin 21.1.0 - 21.6.0)     up
# 23     Apple iOS 15.0 - 15.6 (Darwin 21.1.0 - 21.6.0)     up
# 24                                  Linux 4.15 - 5.19     up
# 25                     Honeywell T5+ or T6 Thermostat     up
# 26                     Honeywell T5+ or T6 Thermostat     up
# 27                                   Linux 3.2 - 4.14     up
# 28                                  Linux 3.10 - 4.11     up
# 29                                  Linux 4.15 - 5.19     up
# 30               Android 6.0 - 9.0 (Linux 3.18 - 4.4)     up
# 31                             HP ProCurve MSM422 WAP     up
# 32     Apple iOS 15.0 - 15.6 (Darwin 21.1.0 - 21.6.0)     up
# 33                     Honeywell T5+ or T6 Thermostat     up
# 34                                   Linux 3.2 - 4.14     up
# 35                                   Linux 3.2 - 4.14     up
# 36                                   Linux 3.2 - 4.14     up
# 37                             Aruba ArubaOS-CX 10.04     up
# 38                Microsoft Windows 10 1607 - 11 23H2     up
